# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Zip_zhvi_bdrmcnt_2_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")
df.head(2)
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State City  \
# 0     91940         0       77449        zip        TX    TX  NaN
# 1     91982         1       77494        zip        TX    TX  NaN
#
#                                   Metro        CountyName  2000-01-31  ...  \
# 0  Houston-The Woodlands-Sugar Land, TX     Harris County     71959.0  ...
# 1  Houston-The Woodlands-Sugar Land, TX  Fort Bend County         NaN  ...
#
#    2022-03-31  2022-04-30  2022-05-31  2022-06-30  2022-07-31  2022-08-31  \
# 0    185348.0    189190.0    192930.0    196007.0    198450.0    199265.0
# 1    349154.0    358056.0    365657.0    370044.0    370861.0    368537.0
#
#    2022-09-30  2022-10-31  2022-11-30  2022-12-31
# 0    199801.0    200478.0    202409.0    203667.0
# 1    368319.0    369042.0    371358.0    371340.0
#
# [2 rows x 285 columns]

# %%
df.describe()
# Out:
#             RegionID      SizeRank    RegionName    2000-01-31    2000-02-29  \
# count   18957.000000  18957.000000  18957.000000  8.634000e+03  8.704000e+03
# mean    80776.607638  10635.727858  48232.044944  1.224189e+05  1.226844e+05
# std     30425.427100   7046.256620  28384.654774  7.838739e+04  7.878241e+04
# min     58196.000000      0.000000   1001.000000  1.412100e+04  1.445000e+04
# 25%     68378.000000   4779.000000  24874.000000  7.636100e+04  7.650425e+04
# 50%     78381.000000   9712.000000  46818.000000  1.052885e+05  1.054710e+05
# 75%     89878.000000  15668.000000  72758.000000  1.444790e+05  1.447740e+05
# max    808739.000000  30657.000000  99901.000000  1.133593e+06  1.153638e+06
#
#          2000-03-31    2000-04-30    2000-05-31    2000-06-30    2000-07-31  \
# count  8.725000e+03  8.737000e+03  8.771000e+03  8.784000e+03  8.794000e+03
# mean   1.230147e+05  1.239211e+05  1.247849e+05  1.257266e+05  1.266891e+05
# ...

# %%
plt.boxplot(df["SizeRank"])
plt.show()

# %%
plt.hist(df["State"])
plt.show()

# %% [markdown]
# Keeping only Boulder Data

# %%
#Preparing List of Boulder ZipCode

zipcodes = [80301, 80302, 80303, 80304, 80305, 80306, 80307, 80309, 80310, 80314]

df_1 = df[df["RegionName"] == 80301]
# Out:
#       RegionID  SizeRank  RegionName RegionType StateName State     City  \
# 4263     93353      4300       80301        zip        CO    CO  Boulder
#
#             Metro      CountyName  2000-01-31  ...  2022-03-31  2022-04-30  \
# 4263  Boulder, CO  Boulder County    153158.0  ...    427282.0    436215.0
#
#       2022-05-31  2022-06-30  2022-07-31  2022-08-31  2022-09-30  2022-10-31  \
# 4263    445438.0    447226.0    443408.0    437188.0    432406.0    434342.0
#
#       2022-11-30  2022-12-31
# 4263    433978.0    433699.0
#
# [1 rows x 285 columns]

# %%
df_80301 = df_1.transpose()
df_80301 = df_80301.drop(index=0, axis = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [62], in <cell line: 2>()
#       1 df_80301 = df_1.transpose()
# ----> 2 df_80301 = df_80301.drop(index=0, axis = 0)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
df_1.head(2)
# Out:
#       RegionID  SizeRank  RegionName RegionType StateName State     City  \
# 4263     93353      4300       80301        zip        CO    CO  Boulder
#
#             Metro      CountyName  2000-01-31  ...  2022-03-31  2022-04-30  \
# 4263  Boulder, CO  Boulder County    153158.0  ...    427282.0    436215.0
#
#       2022-05-31  2022-06-30  2022-07-31  2022-08-31  2022-09-30  2022-10-31  \
# 4263    445438.0    447226.0    443408.0    437188.0    432406.0    434342.0
#
#       2022-11-30  2022-12-31
# 4263    433978.0    433699.0
#
# [1 rows x 285 columns]

# %%
df_80301_1 = df_1[df_1[ ]].values.tolist()

# %%
#df_80301 = pd.df_1.drop(columns = "RegionID")
df_1.drop(columns=["RegionID", "SizeRank", "RegionType", "StateName", "City", "Metro", "CountryName"], axis =1)

# %%
#col_title = [date, price]
#df_80301.iloc[0][0] = 0
#f_80301.columns =  ["date", "price"]
List_1 = df_1["1/31/2000"]
